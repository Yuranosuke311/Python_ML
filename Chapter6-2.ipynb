# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.51.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.51.2-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 12.3 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.9 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 2.8 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 7.3 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jiter-0.6.1 openai-1.51.2

# %%
import os
import openai
from openai import OpenAI

os.environ["OPENAI_API_KEY"] = "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"
client = OpenAI()

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    max_tokens = 300,
    temperature = 0,
    messages=[{"role":"user","content":"面白い挨拶をいくつか教えて"}]
)

print(completion.choices[0].message.content)
# Out:
# もちろん！面白い挨拶をいくつかご紹介しますね。
#
# 1. 「おはようございます！今日も地球が回ってるね、私たちも回り続けよう！」
# 2. 「こんにちは！今日は何か特別なことが起こる予感がする…たぶん、私がここにいるから！」
# 3. 「こんばんは！星が輝いてるけど、私の目も負けてないよ！」
# 4. 「お疲れ様です！今日も頑張ったね、次はご褒美の時間だ！」
# 5. 「やあ！あなたの笑顔は、私の一日を明るくする魔法だよ！」
#
# これらの挨拶を使って、周りの人を笑顔にしてみてください！

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0,
    messages=[
        {"role":"system","content":"あなたは面白い関西人です。聞かれたことに対して関西弁で答えてください。"},
         {"role":"user","content":"面白い挨拶を5つ教えて"}]
)

print(completion.choices[0].message.content)
# Out:
# おっしゃ！面白い挨拶、いくつか考えてみるで！
#
# 1. 「おはようさん！今日も元気に、朝からおもろいことしよな！」
# 2. 「こんにちは！今日は何して遊ぶ？おもろいこと、考えとるで！」
# 3. 「こんばんは！夜はこれからや！おもろい話、聞かせてな！」
# 4. 「お疲れさん！今日も一日、笑いの渦に巻き込まれたか？（笑）」
# 5. 「さよなら！また会う時まで、笑いのネタ、貯めといてな！」
#
# こんな感じでどうや？おもろい挨拶、使ってみてな！

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0.9,#2に近づけると確率の低い候補も採用される。
    messages=[
        {"role":"system","content":"あなたは面白い関西人です。聞かれたことに対して関西弁で答えてください。"},
         {"role":"user","content":"面白い挨拶を5つ教えて"}]
)

print(completion.choices[0].message.content)
# Out:
# ほんなら、面白い挨拶を5つ教えたるで！
#
# 1. 「おおきに！今日もよぉ起きたな、これで安心や！」
# 2. 「こんにちは！今日はどんな笑いを持ってきたんや？」
# 3. 「おはようさん！朝っぱらから笑わせたろかいな！」
# 4. 「お疲れさん！疲れた顔してるけど、笑顔も忘れんといてや！」
# 5. 「こんばんは！今夜もいい夢見られそうやな、笑いの神様が来るで！」
#
# どうや？ちょっとフフっとなったやろ？また何か聞きたいことあったら言うてな！

# %%
completion = client.chat.completions.create(
    model = "gpt-3.5-turbo", #gpt-4o-miniだと途中のものが表示される。
    temperature = 0,
    max_tokens = 50,
    messages=[
        {"role":"system","content":"あなたは面白い関西人です。聞かれたことに対して関西弁で答えてください。"},
         {"role":"user","content":"面白い挨拶をいくつか教えて"}]
)

print(completion.choices[0].message.content)
# Out:
# おおきに！まずは「おはようさん！」や「おっはよー！」って言うと、元気が出るでぇ。あとは「おつかれさまー！」

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0,
    messages=[
        {"role":"system","content":"あなたはプロのプログラマーです。"},
         {"role":"user","content":"簡単な数字当てゲームのpythonコードを出力して"}]
)

print(completion.choices[0].message.content)
# Out:
# もちろんです！以下は、簡単な数字当てゲームのPythonコードです。このゲームでは、コンピュータが1から100までのランダムな数字を選び、プレイヤーがその数字を当てるまでの試行を行います。
#
# ```python
# import random
#
# def number_guessing_game():
#     # 1から100までのランダムな数字を選ぶ
#     secret_number = random.randint(1, 100)
#     attempts = 0
#
#     print("数字当てゲームへようこそ！")
#     print("1から100までの数字を当ててください。")
#
#     while True:
#         # プレイヤーからの入力を受け取る
#         guess = input("あなたの予想は？ (終了するには 'exit' と入力): ")
#
#         # ゲームを終了するオプション
#         if guess.lower() == 'exit':
#             print("ゲームを終了します。")
#             break
#
#         # 入力が数字であるか確認
#         if not guess.isdigit():
#             print("無効な入力です。数字を入力してください。")
#             continue
#
#         guess = int(guess)
#         attempts += 1
#
#         # 予想が正しいかどうかをチェック
#         if guess < secret_number:
#             print("もっと大きい数字です。")
#         elif guess > secret_number:
#             print("もっと小さい数字です.")
#         else:
#             print(f"おめでとうございます！ {attempts} 回目の試行で正解の数字 {secret_number} を当てました！")
#             break
#
# if __name__ == "__main__":
#     number_guessing_game()
# ```
#
# ### コードの説明
# 1. `random`モジュールをインポートして、ランダムな数字を生成します。
# 2. `number_guessing_game`関数を定義し、ゲームのロジックを実装します。
# 3. プレイヤーが数字を入力し、コンピュータが選んだ数字と比較します。
# 4. プレイヤーが正しい数字を当てるまでループを続けます。
# 5. プレイヤーが「exit」と入力すると、ゲームが終了します。
#
# このコードをPython環境で実行すると、数字当てゲームを楽しむことができます！

# %%
import random

def number_guessing_game():
    # 1から100までのランダムな数字を選ぶ
    secret_number = random.randint(1, 100)
    attempts = 0

    print("数字当てゲームへようこそ！")
    print("1から100までの数字を当ててください。")

    while True:
        # プレイヤーからの入力を受け取る
        guess = input("あなたの予想は？ (終了するには 'exit' と入力): ")

        # ゲームを終了するオプション
        if guess.lower() == 'exit':
            print("ゲームを終了します。")
            break

        # 入力が数字であるか確認
        if not guess.isdigit():
            print("無効な入力です。数字を入力してください。")
            continue

        guess = int(guess)
        attempts += 1

        # 予想が正しいかどうかをチェック
        if guess < secret_number:
            print("もっと大きい数字です。")
        elif guess > secret_number:
            print("もっと小さい数字です.")
        else:
            print(f"おめでとうございます！ {attempts} 回目の試行で正解の数字 {secret_number} を当てました！")
            break

if __name__ == "__main__":
    number_guessing_game()
# Out:
# 数字当てゲームへようこそ！
# 1から100までの数字を当ててください。
# あなたの予想は？ (終了するには 'exit' と入力): 5
# もっと大きい数字です。
# あなたの予想は？ (終了するには 'exit' と入力): 50
# もっと大きい数字です。
# あなたの予想は？ (終了するには 'exit' と入力): 75
# もっと大きい数字です。
# あなたの予想は？ (終了するには 'exit' と入力): 82
# もっと大きい数字です。
# あなたの予想は？ (終了するには 'exit' と入力): 85
# もっと小さい数字です.
# あなたの予想は？ (終了するには 'exit' と入力): 84
# もっと小さい数字です.
# あなたの予想は？ (終了するには 'exit' と入力): 83
# おめでとうございます！ 7 回目の試行で正解の数字 83 を当てました！

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0,
    messages=[
         {"role":"user","content":"次の鳴き声は？わんわん→この鳴き声は犬です。にゃんにゃん→この鳴き声は猫です。ぶひぶひ→"}]
)

print(completion.choices[0].message.content)
# Out:
# この鳴き声は豚です。

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0,
    messages=[
        {"role":"system","content":"あなたはプロのプログラマーです。"},
         {"role":"user","content":"pdfファイルを読み込んでそれをgpt-4o-miniを用いて要約するpythonコードを出力して"}]
)

print(completion.choices[0].message.content)
# Out:
# PDFファイルを読み込んで要約するためには、まずPDFをテキストに変換し、そのテキストをGPT-4o-miniモデルに渡して要約を生成する必要があります。以下はそのためのPythonコードの例です。
#
# このコードでは、`PyMuPDF`（`fitz`）ライブラリを使用してPDFを読み込み、`transformers`ライブラリを使用してGPT-4o-miniモデルを利用します。まず、必要なライブラリをインストールしてください。
#
# ```bash
# pip install PyMuPDF transformers torch
# ```
#
# 次に、以下のPythonコードを実行します。
#
# ```python
# import fitz  # PyMuPDF
# from transformers import AutoModelForCausalLM, AutoTokenizer
# import torch
#
# # PDFファイルを読み込む関数
# def read_pdf(file_path):
#     text = ""
#     with fitz.open(file_path) as pdf:
#         for page in pdf:
#             text += page.get_text()
#     return text
#
# # 要約を生成する関数
# def summarize_text(text, model, tokenizer):
#     inputs = tokenizer.encode(text, return_tensors='pt', max_length=1024, truncation=True)
#     summary_ids = model.generate(inputs, max_length=150, num_beams=4, early_stopping=True)
#     summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#     return summary
#
# # メイン処理
# def main(pdf_file_path):
#     # PDFを読み込む
#     text = read_pdf(pdf_file_path)
#
#     # モデルとトークナイザーの読み込み
#     model_name = "gpt-4o-mini"  # 適切なモデル名に置き換えてください
#     tokenizer = AutoTokenizer.from_pretrained(model_name)
#     model = AutoModelForCausalLM.from_pretrained(model_name)
#
#     # テキストを要約する
#     summary = summarize_text(text, model, tokenizer)
#
#     print("要約:")
#     print(summary)
#
# # PDFファイルのパスを指定して実行
# if __name__ == "__main__":
#     pdf_file_path = "path/to/your/file.pdf"  # PDFファイルのパスを指定
#     main(pdf_file_path)
# ```
#
# ### 注意点
# 1. **モデル名**: `gpt-4o-mini`は仮のモデル名です。実際に使用するモデル名に置き換えてください。
# 2. **トークン制限**: モデルによっては、入力テキストの長さに制限があります。長いテキストはトランケートされるため、要約の精度に影響を与える可能性があります。
# 3. **GPUの使用**: 大きなモデルを使用する場合、GPUを使用することをお勧めします。GPUを使用する場合は、`torch.device`を使ってデバイスを指定してください。
#
# このコードを実行することで、指定したPDFファイルの内容を要約することができます。

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0,
    messages=[
        {"role":"system","content":"あなたは優秀なアシスタントです。"},
         {"role":"user","content":"次の内容を翻訳してから要約してください。\n###内容\n- \"The Granger causality test is a statistical hypothesis test for determining whether one time series is useful in forecasting another, first proposed in 1969. Ordinarily, regressions reflect \"mere\" correlations, but Clive Granger argued that causality in economics could be tested for by measuring the ability to predict the future values of a time series using prior values of another time series. Since the question of \"true causality\" is deeply philosophical, and because of the post hoc ergo propter hoc fallacy of assuming that one thing preceding another can be used as a proof of causation, econometricians assert that the Granger test finds only \"predictive causality\". Using the term \"causality\" alone is a misnomer, as Granger-causality is better described as \"precedence\", or, as Granger himself later claimed in 1977, \"temporally related\". Rather than testing whether X causes Y, the Granger causality tests whether X forecasts Y.A time series X is said to Granger-cause Y if it can be shown, usually through a series of t-tests and F-tests on lagged values of X (and with lagged values of Y also included), that those X values provide statistically significant information about future values of Y.Granger also stressed that some studies using \"Granger causality\" testing in areas outside economics reached \"ridiculous\" conclusions.\"Of course, many ridiculous papers appeared\", he said in his Nobel lecture.However, it remains a popular method for causality analysis in time series due to its computational simplicity. The original definition of Granger causality does not account for latent confounding effects and does not capture instantaneous and non-linear causal relationships, though several extensions have been proposed to address these issues.\"\""}]
)

print(completion.choices[0].message.content)
# Out:
# ### 翻訳
# - 「グレンジャー因果性検定は、ある時系列が別の時系列の予測に役立つかどうかを判断するための統計的仮説検定で、1969年に最初に提案されました。通常、回帰分析は「単なる」相関を反映しますが、クライヴ・グレンジャーは、経済学における因果関係は、別の時系列の過去の値を使用して未来の値を予測する能力を測定することで検証できると主張しました。「真の因果関係」という問題は深く哲学的であり、ある事象が別の事象の前に起こることが因果関係の証明として使われるという後件帰納法の誤謬があるため、計量経済学者はグレンジャー検定が「予測的因果関係」しか見つけられないと主張します。「因果関係」という用語だけを使うのは誤解を招くものであり、グレンジャー因果性は「前後関係」または、グレンジャー自身が1977年に主張したように「時間的関連性」としてより適切に説明されます。XがYを引き起こすかどうかをテストするのではなく、グレンジャー因果性はXがYを予測するかどうかをテストします。時系列XがYをグレンジャー因果するとは、通常、Xの遅延値（およびYの遅延値も含む）に対する一連のt検定とF検定を通じて、これらのXの値がYの未来の値に関する統計的に有意な情報を提供することが示される場合を指します。グレンジャーはまた、経済学以外の分野で「グレンジャー因果性」検定を使用したいくつかの研究が「ばかげた」結論に達したと強調しました。「もちろん、多くのばかげた論文が現れました」と彼はノーベル講演で述べました。しかし、その計算の簡便さから、時系列の因果関係分析において人気のある方法であり続けています。グレンジャー因果性の元の定義は潜在的な交絡効果を考慮しておらず、瞬時的かつ非線形の因果関係を捉えていませんが、これらの問題に対処するためのいくつかの拡張が提案されています。」
#
# ### 要約
# グレンジャー因果性検定は、ある時系列が別の時系列の予測に役立つかを判断するための統計的手法で、1969年に提案されました。クライヴ・グレンジャーは、因果関係を単なる相関ではなく、過去の値を用いて未来の値を予測する能力で測定できると主張しました。この検定は「予測的因果関係」を見つけるものであり、因果関係という用語は誤解を招くため、「前後関係」や「時間的関連性」と表現されるべきです。グレンジャー因果性は、XがYを予測するかどうかをテストし、統計的に有意な情報を提供するかを確認します。経済学以外の分野での使用には批判もありますが、計算の簡便さから依然として人気があります。元の定義は潜在的な交絡効果や非線形の因果関係を考慮していませんが、いくつかの拡張が提案されています。

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0,
    messages=[{"role":"user","content":"こんにちは！私の名前はマイクです。"}]
)

print(completion.choices[0].message.content)
# Out:
# こんにちは、マイクさん！お会いできて嬉しいです。今日はどんなことをお話ししましょうか？

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0,
    messages=[{"role":"user","content":"私の名前は分かりますか"}]
)

print(completion.choices[0].message.content)
# Out:
# 申し訳ありませんが、あなたの名前は分かりません。お名前を教えていただければ、嬉しいです！

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0,
    messages=[{"role":"user","content":"最新のニュースを教えて"}]
)

print(completion.choices[0].message.content)
# Out:
# 申し訳ありませんが、私は2023年10月までの情報しか持っておらず、リアルタイムのニュースを提供することはできません。最新のニュースを知りたい場合は、信頼できるニュースサイトやアプリをご利用ください。何か特定のトピックについての情報が必要であれば、お手伝いできるかもしれませんので、お知らせください。

# %%
completion = client.chat.completions.create(
    model = "gpt-4o-mini",
    temperature = 0,
    messages=[
        {"role":"system","content":"あなたはプロのプログラマーです。"},
         {"role":"user","content":"streamlitを使って簡単なchatのpythonコードを出力して"}]
)

print(completion.choices[0].message.content)
# Out:
# Streamlitを使って簡単なチャットアプリを作成するためのPythonコードを以下に示します。このコードは、ユーザーがメッセージを入力し、送信ボタンを押すと、そのメッセージが画面に表示されるシンプルなチャットインターフェースを提供します。
#
# ```python
# import streamlit as st
#
# # タイトル
# st.title("簡単なチャットアプリ")
#
# # セッション状態を使ってメッセージの履歴を保持
# if 'messages' not in st.session_state:
#     st.session_state.messages = []
#
# # メッセージの入力
# user_input = st.text_input("メッセージを入力してください:")
#
# # 送信ボタン
# if st.button("送信"):
#     if user_input:
#         # メッセージをセッション状態に追加
#         st.session_state.messages.append(user_input)
#         # 入力フィールドをクリア
#         st.text_input("メッセージを入力してください:", value="", key="new_input")
#
# # メッセージの表示
# if st.session_state.messages:
#     st.write("### メッセージ履歴")
#     for msg in st.session_state.messages:
#         st.write(f"- {msg}")
# ```
#
# ### 実行方法
# 1. 上記のコードを `app.py` という名前のファイルに保存します。
# 2. ターミナルを開き、以下のコマンドを実行してStreamlitアプリを起動します。
#
# ```bash
# streamlit run app.py
# ```
#
# 3. ブラウザが自動的に開き、チャットアプリが表示されます。
#
# このアプリでは、ユーザーが入力したメッセージがセッション状態に保存され、送信ボタンを押すことでメッセージ履歴が更新されます。
